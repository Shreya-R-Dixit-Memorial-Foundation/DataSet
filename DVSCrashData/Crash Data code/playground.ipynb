# %%
import arcgis
import pandas as pd


def print_result(result):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_colwidth", None)

    output_routes = arcgis.features.FeatureSet.from_dict(result["routes"]).sdf
    print("\n-- Output Routes -- \n")
    print(output_routes[["Name", "Total_TravelTime", "Total_Miles", "Total_Kilometers"]].to_string(index=False))

    directions = result["directions"][0]  #only for the first route
    
    print("\n-- Output Directions -- \n")
    print(f"{directions['routeName']}\n")
    for feature in directions["features"]:
        print(feature["attributes"]["text"])



api_key = " "
portal = arcgis.GIS("https://www.arcgis.com", api_key=api_key)
route = arcgis.network.RouteLayer(portal.properties.helperServices.route.url, gis=portal)
result = route.solve(stops=stops, start_time="now", return_directions=True, directions_language="en")
print_result(result)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17826, in _GISResource._refresh(self)
#   17825     else:
# > 17826         dictdata = self._con.post(
#   17827             self.url, params
#   17828         )  # , token=self._lazy_token)
#   17829 except Exception as e:
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1524, in Connection.post(self, path, params, files, **kwargs)
#    1523     return resp
# -> 1524 return self._handle_response(
#    1525     resp=resp,
#    1526     out_path=out_path,
#    1527     file_name=file_name,
#    1528     try_json=try_json,
#    1529     force_bytes=kwargs.pop("force_bytes", False),
#    1530 )
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:982, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     981     if "error" in data and ignore_error_key == False:
# --> 982         raise Exception(data["error"])
#     983 else:
#
# Exception: {'code': 499, 'message': 'Token Required', 'details': []}
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17863, in _GISResource._hydrate(self)
#   17862 try:
# > 17863     self._refresh()
#   17865 except HTTPError as httperror:  # service maybe down
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17835, in _GISResource._refresh(self)
#   17834 elif str(e).lower().find("token required") > -1:
# > 17835     dictdata = self._con.get(self.url, params)
#   17836 else:
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:862, in Connection.get(self, path, params, **kwargs)
#     861     return resp
# --> 862 return self._handle_response(
#     863     resp,
#     864     file_name,
#     865     out_path,
#     866     try_json,
#     867     force_bytes=kwargs.pop("force_bytes", False),
#     868     ignore_error_key=ignore_error_key,
#     869 )
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:982, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     981     if "error" in data and ignore_error_key == False:
# --> 982         raise Exception(data["error"])
#     983 else:
#
# Exception: {'code': 499, 'message': 'Token Required', 'details': []}
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17826, in _GISResource._refresh(self)
#   17825     else:
# > 17826         dictdata = self._con.post(
#   17827             self.url, params
#   17828         )  # , token=self._lazy_token)
#   17829 except Exception as e:
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1524, in Connection.post(self, path, params, files, **kwargs)
#    1523     return resp
# -> 1524 return self._handle_response(
#    1525     resp=resp,
#    1526     out_path=out_path,
#    1527     file_name=file_name,
#    1528     try_json=try_json,
#    1529     force_bytes=kwargs.pop("force_bytes", False),
#    1530 )
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:982, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     981     if "error" in data and ignore_error_key == False:
# --> 982         raise Exception(data["error"])
#     983 else:
#
# Exception: {'code': 499, 'message': 'Token Required', 'details': []}
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 25
#      23 portal = arcgis.GIS("https://www.arcgis.com", api_key=api_key)
#      24 route = arcgis.network.RouteLayer(portal.properties.helperServices.route.url, gis=portal)
# ---> 25 result = route.solve(stops=stops, start_time="now", return_directions=True, directions_language="en")
#      26 print_result(result)
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\network\_layer.py:512, in RouteLayer.solve(self, stops, barriers, polyline_barriers, polygon_barriers, travel_mode, attribute_parameter_values, return_directions, return_routes, return_stops, return_barriers, return_polyline_barriers, return_polygon_barriers, out_sr, ignore_invalid_locations, output_lines, find_best_sequence, preserve_first_stop, preserve_last_stop, use_time_windows, start_time, start_time_is_utc, accumulate_attribute_names, impedance_attribute_name, restriction_attribute_names, restrict_u_turns, use_hierarchy, directions_language, directions_output_type, directions_style_name, directions_length_units, directions_time_attribute_name, output_geometry_precision, output_geometry_precision_units, return_z, overrides, preserve_objectid, future, time_windows_are_utc, return_traversed_edges, return_traversed_junctions, return_traversed_turns, geometry_precision, geometry_precision_z, geometry_precision_m)
#     256 def solve(
#     257     self,
#     258     stops: Union[list[Point], list[FeatureSet], FeatureSet],
#    (...)
#     301     geometry_precision_m: Optional[int] = None,
#     302 ):
#     303     """
#     304     The solve operation is performed on a network layer resource.
#     305     The solve operation is supported on a network layer whose layerType
#    (...)
#     509
#     510     """
# --> 512     if not self.properties.layerType == "esriNAServerRouteLayer":
#     513         raise ValueError(
#     514             "The solve operation is supported on a network "
#     515             "layer of Route type only"
#     516         )
#     518     url = self._url + "/solve"
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17849, in _GISResource.properties(self)
#   17847     return self._lazy_properties
#   17848 else:
# > 17849     self._hydrate()
#   17850     return self._lazy_properties
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17886, in _GISResource._hydrate(self)
#   17883 try:
#   17884     # try as a public server
#   17885     self._lazy_token = None
# > 17886     self._refresh()
#   17888 except HTTPError as httperror:
#   17889     _log.error(httperror)
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\__init__.py:17835, in _GISResource._refresh(self)
#   17831     dictdata = self._con.get(
#   17832         self.url, params
#   17833     )  # , token=self._lazy_token)
#   17834 elif str(e).lower().find("token required") > -1:
# > 17835     dictdata = self._con.get(self.url, params)
#   17836 else:
#   17837     raise e
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:862, in Connection.get(self, path, params, **kwargs)
#     860 if return_raw_response:
#     861     return resp
# --> 862 return self._handle_response(
#     863     resp,
#     864     file_name,
#     865     out_path,
#     866     try_json,
#     867     force_bytes=kwargs.pop("force_bytes", False),
#     868     ignore_error_key=ignore_error_key,
#     869 )
#
# File c:\Users\prana\anaconda3\envs\MITCOURSE\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:982, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     980     data = json.loads(data)
#     981     if "error" in data and ignore_error_key == False:
# --> 982         raise Exception(data["error"])
#     983 else:
#     984     try:
#
# Exception: {'code': 499, 'message': 'Token Required', 'details': []}

# %%
import json
path0 = result["routes"]["features"][0]
route_coordinates = path0["attributes"]["SHAPE"]["paths"][0]
print(json.dumps(route_coordinates, sort_keys=True, indent=4))
# Out:
# [
#     [
#         -93.43656506499997,
#         44.86048000000005
#     ],
#     [
#         -93.43698999999998,
#         44.86048000000005
#     ],
#     [
#         -93.43699999999995,
#         44.86065000000008
#     ],
#     [
#         -93.43698999999998,
#         44.86081000000007
#     ],
#     [
#         -93.43699999999995,
#         44.86099000000007
#     ],
#     [
#         -93.43699999999995,
#         44.86117000000007
#     ],
#     [
#         -93.43697999999995,
#         44.861320000000035
#     ],
#     [
#         -93.43709999999999,
#         44.86142000000007
#     ],
#     [
#         -93.43702999999994,
#         44.86211000000003
#     ],
#     [
#         -93.43903999999998,
#         44.86205000000007
#     ],
#     [
#         -93.43996999999996,
#         44.861950000000036
#     ],
#     [
#         -93.44084999999995,
#         44.86167000000006
#     ],
#     [
#         -93.44176999999996,
#         44.861330000000066
#     ],
#     [
#         -93.44198999999998,
#         44.861230000000035
#     ],
#     [
#         -93.44182999999998,
#         44.86111000000005
#     ],
#     [
#         -93.44094999999999,
#         44.86041000000006
#     ],
#     [
#         -93.44077999999996,
#         44.86027000000007
#     ],
#     [
#         -93.44017999999994,
#         44.85982000000007
#     ],
#     [
#         -93.44120999999996,
#   [-93.437       44.86099   ]
#   [-93.437       44.86117   ]
#   [-93.43698     44.86132   ]
#   [-93.4371      44.86142   ]
#   [-93.43703     44.86211   ]
#   [-93.43904     44.86205   ]
#   [-93.43997     44.86195   ]
#   [-93.44085     44.86167   ]
#   [-93.44177     44.86133   ]
#   [-93.44199     44.86123   ]
#   [-93.44183     44.86111   ]
#   [-93.44095     44.86041   ]
#   [-93.44078     44.86027   ]
#   [-93.44018     44.85982   ]
#   [-93.44121     44.85909   ]
#   [-93.44205     44.85866   ]
#   [-93.44228     44.85862   ]
#   [-93.443       44.85862   ]
#   [-93.4439      44.85894   ]
#   [-93.44454     44.85919   ]
#   [-93.44578     44.85937   ]
#   [-93.44629     44.85929   ]
#   [-93.44749     44.85899   ]
#   [-93.44837     44.85874   ]
#   [-93.44888     44.85851   ]
#   [-93.4492      44.85833   ]
#   [-93.44953     44.85815   ]
#   [-93.45027     44.85774   ]
#   [-93.45092     44.85743   ]
#   [-93.45185     44.85718   ]
#   [-93.45295     44.85718   ]
#   [-93.455       44.85783   ]
#   [-93.4559      44.85795   ]
#   [-93.45766     44.85792   ]
#   [-93.4578      44.85792   ]
#   [-93.46015     44.85802   ]
#   [-93.46365     44.85778   ]
#   [-93.46503     44.85763   ]
#   [-93.46539     44.85758   ]
#   [-93.46636     44.85741   ]
#   [-93.46729     44.85728   ]
#   [-93.46758     44.85725   ]
#   [-93.4688      44.8572    ]
#   [-93.46999     44.85738   ]
#   [-93.47053     44.8575    ]
#   [-93.47268     44.85804   ]
#   [-93.4733      44.85729   ]
#   [-93.47399     44.85767   ]
#   [-93.47472     44.85781   ]
#   [-93.47507     44.85775   ]
#   [-93.47585     44.85812   ]
#   [-93.47663     44.85814   ]
#   [-93.47724     44.85783   ]
#   [-93.47733     44.85755   ]
#   [-93.47779     44.85716   ]
#   [-93.47815     44.85718   ]
#   [-93.47820241  44.85718   ]]]

# %%
crashes = [
    [-93.46523287590787, 44.85242623824904]
]


threshold_distance_meters = 100  # Example: 100 meters

# Loop through the coordinates and check for intersections
intersections = []

for coordinate in crashes:
    # Create a point geometry from the coordinate
    point_geometry = Point({"x": coordinate[0], "y": coordinate[1], "spatialReference": {"wkid": 4326}})

    # Check for intersections with the feature set
    for feature in route_feature_set.features:
        # Convert the polyline object to a Polyline class instance
        polyline = Polyline(feature.geometry)
        
        point_geometry = point_geometry.project_as(polyline.spatial_reference)


        # Calculate the distance between the point and the polyline
        distance = polyline.distance_to(point_geometry)
        print(distance)
        # Check if the distance is less than the threshold
        if distance is not None and distance <= threshold_distance_meters:
            intersections.append((coordinate, feature.attributes))

# Print the intersections found
for coordinate, attributes in intersections:
    print(f"Intersection at coordinate {coordinate} with attributes {attributes}")
# Out:
# None

# %%
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-3aaf1a75-7425-4df6-a922-5ebd88415170"><img src=""></img></div>
# <div class="map-html-embed-preview-3aaf1a75-7425-4df6-a922-5ebd88415170"></div>

# %%
from arcgis.geometry import distance

point1_coords = [-118.24532, 34.05223] 
point2_coords = [-122.4194, 37.7749]

point1 = Point({"x": point1_coords[0], "y": point1_coords[1], "spatialReference": {"wkid": 4326}})
point2 = Point({"x": point2_coords[0], "y": point2_coords[1], "spatialReference": {"wkid": 4326}})

distance_meters = distance(point1.spatial_reference, [point1], point2, "aopple[aposd]")
print(distance_meters)
